# %% [markdown]
# Índice

# %% [markdown]
# - [Motivação](#Motivação)
# - [Ferramentas](#Ferramentas)
#     - [Anaconda: Jupyter e Python IDE](#Anaconda:-Jupyter-e-Python-IDE)
#     - [Git](#Git)
#     - [Evernote](#Git)
# - [A matemática necessária](#A-matemática-necessária)
#     - [Rastrigin](#Rastrigin)
#         - [Rastrigin dentro de um algoritmo bioinspirado](#Rastrigin-dentro-de-um-algoritmo-bioinspirado)
#     - [Números Aleatórios](#Números-Aleatórios)
#         - [Outra forma - variáveis aleatórias uniformes e Gaussianas](#Outra-forma---variáveis-aleatórias-uniformes-e-Gaussianas)
#     - [Mais Aplicações](#Mais-Aplicações)

# %% [markdown]
# # Motivação

# %%
pathFileImages = 'C:/Users/claud/OneDrive/Documentos/Figuras Aula 0/'

from IPython.display import Image
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math
import os

# %%
Image(filename = pathFileImages + 'BigData.png')

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# https://medium.com/basic-income/deep-learning-is-going-to-teach-us-all-the-lesson-of-our-lives-jobs-are-for-machines-7c6442e37a49

# %%
Image(filename = pathFileImages + 'Go1.png')

# %%
Image(filename = pathFileImages + 'Go2.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-4ede5417bdac> in <module>()
# ----> 1 Image(filename = pathFileImages + 'Go2.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# ## The AI Revolution

# %% [markdown]
# https://waitbutwhy.com/2015/01/artificial-intelligence-revolution-1.html

# %% [markdown]
# https://waitbutwhy.com/2015/01/artificial-intelligence-revolution-2.html

# %%
Image(filename = pathFileImages + 'AIRevolution.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-9e87dd5ca84f> in <module>()
# ----> 1 Image(filename = pathFileImages + 'AIRevolution.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# # Ferramentas

# %% [markdown]
# ## Anaconda: Jupyter e Python IDE

# %%
Image(filename = pathFileImages + 'AnacondaJupyter.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-c6d6d45db552> in <module>()
# ----> 1 Image(filename = pathFileImages + 'AnacondaJupyter.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# ## Git

# %%
Image(filename = pathFileImages + 'GitServices.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-023853767b36> in <module>()
# ----> 1 Image(filename = pathFileImages + 'GitServices.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# ## Evernote

# %%
Image(filename = pathFileImages + 'Evernote.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-a2638d835dce> in <module>()
# ----> 1 Image(filename = pathFileImages + 'Evernote.jpg')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# # A matemática necessária

# %% [markdown]
# ## Rastrigin

# %%
Image(filename = pathFileImages + 'Rastrigin.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-eaa8b59acaf1> in <module>()
# ----> 1 Image(filename = pathFileImages + 'Rastrigin.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %%
Image(filename = pathFileImages + 'RastriginEquation.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-dfff43c298f0> in <module>()
# ----> 1 Image(filename = pathFileImages + 'RastriginEquation.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %%
"""
https://en.wikipedia.org/wiki/Rastrigin_function
Non-convex function for testing optimization algorithms.
"""

"""
Fonte: https://gist.github.com/miku/fca6afe05d65302f14c2b6f5242458d6#file-rastrigin-py
"""

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import math
import matplotlib.pyplot as plt
import numpy as np

def rastrigin(*X, **kwargs):
    A = kwargs.get('A', 10)
    print(A)
    #print(X)
    return A + sum([(x**2 - A * np.cos(2 * math.pi * x)) for x in X])

if __name__ == '__main__':
    X = np.linspace(-4, 4, 200)    
    Y = np.linspace(-4, 4, 200)    
    

    X, Y = np.meshgrid(X, Y)
    print(X)

    Z = rastrigin(X, Y, A=10)

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.plasma, linewidth=0, antialiased=False)    
    plt.savefig('rastrigin.png')
    #plt.show( )
# Out:
# [[-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]
#  [-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]
#  [-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]
#  ...,
#  [-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]
#  [-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]
#  [-4.         -3.95979899 -3.91959799 ...,  3.91959799  3.95979899  4.        ]]
# 10

# %% [markdown]
# ### Rastrigin dentro de um algoritmo bioinspirado

# %%
Image(filename = pathFileImages + 'RastriginPythonLatexCode.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-1728ffa7a8a4> in <module>()
# ----> 1 Image(filename = pathFileImages + 'RastriginPythonLatexCode.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# ...

# %% [markdown]
# Fontes: https://gist.github.com/miku/fca6afe05d65302f14c2b6f5242458d6#file-rastrigin-py e https://www.sfu.ca/~ssurjano/rastr.html

# %% [markdown]
# ## Números Aleatórios

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.Series(np.random.randn(1000))

print(data.tail())

data.hist(figsize=(8, 6))

plt.show()
# Out:
# 995    0.400706
# 996   -1.073775
# 997    1.253807
# 998    0.300731
# 999    0.718853
# dtype: float64

# %%
data1 = pd.Series(np.random.randn(1000))

print(data1.tail())

data1.hist(by=[np.random.randint(0, 2, 1000)], figsize=(6, 4))

plt.show()
# Out:
# 995    0.766267
# 996    1.237754
# 997    0.199565
# 998   -0.653624
# 999    1.149722
# dtype: float64

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])


df4.plot.hist(alpha=0.9)

plt.show()

# %% [markdown]
# ### Outra forma - variáveis aleatórias uniformes e Gaussianas

# %%
sigma = 1
mi = 0

#https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.random.randn.html#numpy.random.randn
a = sigma * np.random.randn(1000000, 1) + mi

b = np.random.rand(100000, 1)

#print(a)

plt.hist(a, bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()


plt.hist(b, bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()

# %% [markdown]
# ## Mais Aplicações

# %%
Image(filename = pathFileImages + 'Dissertação do Caio.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-71-9d923b2c8320> in <module>()
# ----> 1 Image(filename = pathFileImages + 'Dissertação do Caio.png')
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# C:\Anaconda3\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %% [markdown]
# ## Meshgrid - numpy

# %% [markdown]
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.meshgrid.html

# %%
nx, ny = (3, 3)
x = np.linspace(np.pi/2, np.pi, nx)
print(x)
y = np.linspace(np.pi, 1.5*np.pi, ny)
print(y,'\n')
xx, yy = np.meshgrid(x, y)
print(xx)
print(yy,'\n')

z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)

print(z)
# Out:
# [ 1.57079633  2.35619449  3.14159265]
# [ 3.14159265  3.92699082  4.71238898]
#
# [[ 1.57079633  2.35619449  3.14159265]
#  [ 1.57079633  2.35619449  3.14159265]
#  [ 1.57079633  2.35619449  3.14159265]]
# [[ 3.14159265  3.14159265  3.14159265]
#  [ 3.92699082  3.92699082  3.92699082]
#  [ 4.71238898  4.71238898  4.71238898]]
#
# [[-0.01842905  0.01833797  0.03935584]
#  [-0.04582268  0.04058498  0.00622604]
#  [-0.01794641  0.0177773   0.01912146]]

# %%
M = np.random.rand(3,3)
M
# Out:
# array([[ 0.2313242 ,  0.50596701,  0.21542169],
#        [ 0.66673799,  0.62792189,  0.91058819],
#        [ 0.8558556 ,  0.28890251,  0.69313119]])

# %%
np.save('saved-matrix.npy', M)
np.load('saved-matrix.npy')
# Out:
# array([[ 0.2313242 ,  0.50596701,  0.21542169],
#        [ 0.66673799,  0.62792189,  0.91058819],
#        [ 0.8558556 ,  0.28890251,  0.69313119]])

# %%
os.system('head saved-matrix.npy')
# Out:
# 0
